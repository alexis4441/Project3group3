# %% [markdown]
# ## Project 3 - Wildfires

# %% [markdown]
# A wildfire is an uncontrolled fire that burns in the wildland vegetation, including rural areas, shrublands/grasslands, savannas, croplands, etc. We will be using datasets that will help us identify how much area is burnt every week per country, the total land area burnt per year, as well as the type of land (ecosystem) burnt per year. The data we will be using were taken from the years 2012-2022.

# %%
import pandas as pd
from pathlib import Path
import hvplot.pandas
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
from scipy.stats import linregress, pearsonr
import requests
import time
from pathlib import Path
import folium
from ipywidgets import interact, Dropdown, Output
from geopy.geocoders import Nominatim
import plotly.express as px
import dash
from dash import dcc, html, Input, Output
import plotly.graph_objs as go

# %%
# Create a path to CSV files, read the path and print DataFrame for the first CSV file
file_path = ("/Users/artemzalivchiy/Desktop/Project3/1-cumulative-area-burnt-by-wildfires-by-week.csv")
wildfires = pd.read_csv(file_path)
wildfires
# Out:
#             Entity Code  Year  Cumulative area burnt by wildfires in 2024  \
# 0      Afghanistan  AFG     1                                       391.0
# 1      Afghanistan  AFG     2                                       559.0
# 2      Afghanistan  AFG     3                                       841.0
# 3      Afghanistan  AFG     4                                       841.0
# 4      Afghanistan  AFG     5                                       841.0
# ...            ...  ...   ...                                         ...
# 13411     Zimbabwe  ZWE    48                                         NaN
# 13412     Zimbabwe  ZWE    49                                         NaN
# 13413     Zimbabwe  ZWE    50                                         NaN
# 13414     Zimbabwe  ZWE    51                                         NaN
# 13415     Zimbabwe  ZWE    52                                         NaN
#
#        Cumulative area burnt by wildfires in 2023  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ...                                           ...
# 13411                                     2358715
# 13412                                     2383435
# 13413                                     2385610
# 13414                                     2385610
# 13415                                     2385610
#
#        Cumulative area burnt by wildfires in 2022  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                             215
# ...                                           ...
# 13411                                     3017486
# 13412                                     3017486
# 13413                                     3017694
# 13414                                     3017694
# 13415                                     3018840
#
#        Cumulative area burnt by wildfires in 2021  \
# 0                                            1246
# 1                                            2680
# 2                                            3539
# 3                                            3719
# 4                                            4131
# ...                                           ...
# 13411                                     2090438
# 13412                                     2108381
# 13413                                     2113226
# 13414                                     2113226
# 13415                                     2113478
#
#        Cumulative area burnt by wildfires in 2020  \
# 0                                               0
# 1                                             963
# 2                                            1181
# 3                                            2030
# 4                                            3351
# ...                                           ...
# 13411                                     1221386
# 13412                                     1221386
# 13413                                     1221386
# 13414                                     1221548
# 13415                                     1221719
#
#        Cumulative area burnt by wildfires in 2019  \
# 0                                               0
# 1                                              20
# 2                                              20
# 3                                              20
# 4                                              20
# ...                                           ...
# 13411                                     2752906
# 13412                                     2753700
# 13413                                     2754152
# 13414                                     2756253
# 13415                                     2757233
#
#        Cumulative area burnt by wildfires in 2018  \
# 0                                             117
# 1                                             117
# 2                                             264
# 3                                             411
# 4                                             411
# ...                                           ...
# 13411                                     2705357
# 13412                                     2705357
# 13413                                     2707267
# 13414                                     2709955
# 13415                                     2710993
#
#        Cumulative area burnt by wildfires in 2017  \
# 0                                               0
# 1                                              82
# 2                                             129
# 3                                             129
# 4                                             129
# ...                                           ...
# 13411                                     2437024
# 13412                                     2441223
# 13413                                     2443004
# 13414                                     2443661
# 13415                                     2445508
#
#        Cumulative area burnt by wildfires in 2016  \
# 0                                               0
# 1                                               0
# 2                                             390
# 3                                             390
# 4                                            1043
# ...                                           ...
# 13411                                     2176472
# 13412                                     2178815
# 13413                                     2179147
# 13414                                     2179147
# 13415                                     2179365
#
#        Cumulative area burnt by wildfires in 2015  \
# 0                                             368
# 1                                             425
# 2                                             425
# 3                                             425
# 4                                             425
# ...                                           ...
# 13411                                     3182494
# 13412                                     3192311
# 13413                                     3194733
# 13414                                     3195377
# 13415                                     3196594
#
#        Cumulative area burnt by wildfires in 2014  \
# 0                                               0
# 1                                             426
# 2                                             426
# 3                                             426
# 4                                             426
# ...                                           ...
# 13411                                     2831917
# 13412                                     2861358
# 13413                                     2862483
# 13414                                     2862758
# 13415                                     2863008
#
#        Cumulative area burnt by wildfires in 2013  \
# 0                                               0
# 1                                               0
# 2                                              54
# 3                                             362
# 4                                             379
# ...                                           ...
# 13411                                     2556610
# 13412                                     2562822
# 13413                                     2564134
# 13414                                     2564322
# 13415                                     2564322
#
#        Cumulative area burnt by wildfires in 2012
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                             368
# 4                                             597
# ...                                           ...
# 13411                                     3266499
# 13412                                     3269141
# 13413                                     3270515
# 13414                                     3271228
# 13415                                     3271385
#
# [13416 rows x 16 columns]

# %%
#Drop unneeded columns
wildfires_clean = wildfires.drop(columns=['Cumulative area burnt by wildfires in 2024', 'Cumulative area burnt by wildfires in 2023'])
wildfires_clean
# Out:
#             Entity Code  Year  Cumulative area burnt by wildfires in 2022  \
# 0      Afghanistan  AFG     1                                           0
# 1      Afghanistan  AFG     2                                           0
# 2      Afghanistan  AFG     3                                           0
# 3      Afghanistan  AFG     4                                           0
# 4      Afghanistan  AFG     5                                         215
# ...            ...  ...   ...                                         ...
# 13411     Zimbabwe  ZWE    48                                     3017486
# 13412     Zimbabwe  ZWE    49                                     3017486
# 13413     Zimbabwe  ZWE    50                                     3017694
# 13414     Zimbabwe  ZWE    51                                     3017694
# 13415     Zimbabwe  ZWE    52                                     3018840
#
#        Cumulative area burnt by wildfires in 2021  \
# 0                                            1246
# 1                                            2680
# 2                                            3539
# 3                                            3719
# 4                                            4131
# ...                                           ...
# 13411                                     2090438
# 13412                                     2108381
# 13413                                     2113226
# 13414                                     2113226
# 13415                                     2113478
#
#        Cumulative area burnt by wildfires in 2020  \
# 0                                               0
# 1                                             963
# 2                                            1181
# 3                                            2030
# 4                                            3351
# ...                                           ...
# 13411                                     1221386
# 13412                                     1221386
# 13413                                     1221386
# 13414                                     1221548
# 13415                                     1221719
#
#        Cumulative area burnt by wildfires in 2019  \
# 0                                               0
# 1                                              20
# 2                                              20
# 3                                              20
# 4                                              20
# ...                                           ...
# 13411                                     2752906
# 13412                                     2753700
# 13413                                     2754152
# 13414                                     2756253
# 13415                                     2757233
#
#        Cumulative area burnt by wildfires in 2018  \
# 0                                             117
# 1                                             117
# 2                                             264
# 3                                             411
# 4                                             411
# ...                                           ...
# 13411                                     2705357
# 13412                                     2705357
# 13413                                     2707267
# 13414                                     2709955
# 13415                                     2710993
#
#        Cumulative area burnt by wildfires in 2017  \
# 0                                               0
# 1                                              82
# 2                                             129
# 3                                             129
# 4                                             129
# ...                                           ...
# 13411                                     2437024
# 13412                                     2441223
# 13413                                     2443004
# 13414                                     2443661
# 13415                                     2445508
#
#        Cumulative area burnt by wildfires in 2016  \
# 0                                               0
# 1                                               0
# 2                                             390
# 3                                             390
# 4                                            1043
# ...                                           ...
# 13411                                     2176472
# 13412                                     2178815
# 13413                                     2179147
# 13414                                     2179147
# 13415                                     2179365
#
#        Cumulative area burnt by wildfires in 2015  \
# 0                                             368
# 1                                             425
# 2                                             425
# 3                                             425
# 4                                             425
# ...                                           ...
# 13411                                     3182494
# 13412                                     3192311
# 13413                                     3194733
# 13414                                     3195377
# 13415                                     3196594
#
#        Cumulative area burnt by wildfires in 2014  \
# 0                                               0
# 1                                             426
# 2                                             426
# 3                                             426
# 4                                             426
# ...                                           ...
# 13411                                     2831917
# 13412                                     2861358
# 13413                                     2862483
# 13414                                     2862758
# 13415                                     2863008
#
#        Cumulative area burnt by wildfires in 2013  \
# 0                                               0
# 1                                               0
# 2                                              54
# 3                                             362
# 4                                             379
# ...                                           ...
# 13411                                     2556610
# 13412                                     2562822
# 13413                                     2564134
# 13414                                     2564322
# 13415                                     2564322
#
#        Cumulative area burnt by wildfires in 2012
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                             368
# 4                                             597
# ...                                           ...
# 13411                                     3266499
# 13412                                     3269141
# 13413                                     3270515
# 13414                                     3271228
# 13415                                     3271385
#
# [13416 rows x 14 columns]

# %%
# Rename columns 
area_burnt_weekly = wildfires_clean.rename(columns={"Entity":"Country", "Year":"Week"})
area_burnt_weekly
# Out:
#            Country Code  Week  Cumulative area burnt by wildfires in 2022  \
# 0      Afghanistan  AFG     1                                           0
# 1      Afghanistan  AFG     2                                           0
# 2      Afghanistan  AFG     3                                           0
# 3      Afghanistan  AFG     4                                           0
# 4      Afghanistan  AFG     5                                         215
# ...            ...  ...   ...                                         ...
# 13411     Zimbabwe  ZWE    48                                     3017486
# 13412     Zimbabwe  ZWE    49                                     3017486
# 13413     Zimbabwe  ZWE    50                                     3017694
# 13414     Zimbabwe  ZWE    51                                     3017694
# 13415     Zimbabwe  ZWE    52                                     3018840
#
#        Cumulative area burnt by wildfires in 2021  \
# 0                                            1246
# 1                                            2680
# 2                                            3539
# 3                                            3719
# 4                                            4131
# ...                                           ...
# 13411                                     2090438
# 13412                                     2108381
# 13413                                     2113226
# 13414                                     2113226
# 13415                                     2113478
#
#        Cumulative area burnt by wildfires in 2020  \
# 0                                               0
# 1                                             963
# 2                                            1181
# 3                                            2030
# 4                                            3351
# ...                                           ...
# 13411                                     1221386
# 13412                                     1221386
# 13413                                     1221386
# 13414                                     1221548
# 13415                                     1221719
#
#        Cumulative area burnt by wildfires in 2019  \
# 0                                               0
# 1                                              20
# 2                                              20
# 3                                              20
# 4                                              20
# ...                                           ...
# 13411                                     2752906
# 13412                                     2753700
# 13413                                     2754152
# 13414                                     2756253
# 13415                                     2757233
#
#        Cumulative area burnt by wildfires in 2018  \
# 0                                             117
# 1                                             117
# 2                                             264
# 3                                             411
# 4                                             411
# ...                                           ...
# 13411                                     2705357
# 13412                                     2705357
# 13413                                     2707267
# 13414                                     2709955
# 13415                                     2710993
#
#        Cumulative area burnt by wildfires in 2017  \
# 0                                               0
# 1                                              82
# 2                                             129
# 3                                             129
# 4                                             129
# ...                                           ...
# 13411                                     2437024
# 13412                                     2441223
# 13413                                     2443004
# 13414                                     2443661
# 13415                                     2445508
#
#        Cumulative area burnt by wildfires in 2016  \
# 0                                               0
# 1                                               0
# 2                                             390
# 3                                             390
# 4                                            1043
# ...                                           ...
# 13411                                     2176472
# 13412                                     2178815
# 13413                                     2179147
# 13414                                     2179147
# 13415                                     2179365
#
#        Cumulative area burnt by wildfires in 2015  \
# 0                                             368
# 1                                             425
# 2                                             425
# 3                                             425
# 4                                             425
# ...                                           ...
# 13411                                     3182494
# 13412                                     3192311
# 13413                                     3194733
# 13414                                     3195377
# 13415                                     3196594
#
#        Cumulative area burnt by wildfires in 2014  \
# 0                                               0
# 1                                             426
# 2                                             426
# 3                                             426
# 4                                             426
# ...                                           ...
# 13411                                     2831917
# 13412                                     2861358
# 13413                                     2862483
# 13414                                     2862758
# 13415                                     2863008
#
#        Cumulative area burnt by wildfires in 2013  \
# 0                                               0
# 1                                               0
# 2                                              54
# 3                                             362
# 4                                             379
# ...                                           ...
# 13411                                     2556610
# 13412                                     2562822
# 13413                                     2564134
# 13414                                     2564322
# 13415                                     2564322
#
#        Cumulative area burnt by wildfires in 2012
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                             368
# 4                                             597
# ...                                           ...
# 13411                                     3266499
# 13412                                     3269141
# 13413                                     3270515
# 13414                                     3271228
# 13415                                     3271385
#
# [13416 rows x 14 columns]

# %%
area_burnt_weekly2 = area_burnt_weekly[["Country", "Week", "Cumulative area burnt by wildfires in 2022","Cumulative area burnt by wildfires in 2021","Cumulative area burnt by wildfires in 2020","Cumulative area burnt by wildfires in 2019","Cumulative area burnt by wildfires in 2018","Cumulative area burnt by wildfires in 2017","Cumulative area burnt by wildfires in 2016","Cumulative area burnt by wildfires in 2015","Cumulative area burnt by wildfires in 2014","Cumulative area burnt by wildfires in 2013", "Cumulative area burnt by wildfires in 2012"]].copy()
area_burnt_weekly2.astype(str)
area_burnt_weekly2.set_index("Country",inplace=True)
area_burnt_weekly2
# Out:
#              Week  Cumulative area burnt by wildfires in 2022  \
# Country
# Afghanistan     1                                           0
# Afghanistan     2                                           0
# Afghanistan     3                                           0
# Afghanistan     4                                           0
# Afghanistan     5                                         215
# ...           ...                                         ...
# Zimbabwe       48                                     3017486
# Zimbabwe       49                                     3017486
# Zimbabwe       50                                     3017694
# Zimbabwe       51                                     3017694
# Zimbabwe       52                                     3018840
#
#              Cumulative area burnt by wildfires in 2021  \
# Country
# Afghanistan                                        1246
# Afghanistan                                        2680
# Afghanistan                                        3539
# Afghanistan                                        3719
# Afghanistan                                        4131
# ...                                                 ...
# Zimbabwe                                        2090438
# Zimbabwe                                        2108381
# Zimbabwe                                        2113226
# Zimbabwe                                        2113226
# Zimbabwe                                        2113478
#
#              Cumulative area burnt by wildfires in 2020  \
# Country
# Afghanistan                                           0
# Afghanistan                                         963
# Afghanistan                                        1181
# Afghanistan                                        2030
# Afghanistan                                        3351
# ...                                                 ...
# Zimbabwe                                        1221386
# Zimbabwe                                        1221386
# Zimbabwe                                        1221386
# Zimbabwe                                        1221548
# Zimbabwe                                        1221719
#
#              Cumulative area burnt by wildfires in 2019  \
# Country
# Afghanistan                                           0
# Afghanistan                                          20
# Afghanistan                                          20
# Afghanistan                                          20
# Afghanistan                                          20
# ...                                                 ...
# Zimbabwe                                        2752906
# Zimbabwe                                        2753700
# Zimbabwe                                        2754152
# Zimbabwe                                        2756253
# Zimbabwe                                        2757233
#
#              Cumulative area burnt by wildfires in 2018  \
# Country
# Afghanistan                                         117
# Afghanistan                                         117
# Afghanistan                                         264
# Afghanistan                                         411
# Afghanistan                                         411
# ...                                                 ...
# Zimbabwe                                        2705357
# Zimbabwe                                        2705357
# Zimbabwe                                        2707267
# Zimbabwe                                        2709955
# Zimbabwe                                        2710993
#
#              Cumulative area burnt by wildfires in 2017  \
# Country
# Afghanistan                                           0
# Afghanistan                                          82
# Afghanistan                                         129
# Afghanistan                                         129
# Afghanistan                                         129
# ...                                                 ...
# Zimbabwe                                        2437024
# Zimbabwe                                        2441223
# Zimbabwe                                        2443004
# Zimbabwe                                        2443661
# Zimbabwe                                        2445508
#
#              Cumulative area burnt by wildfires in 2016  \
# Country
# Afghanistan                                           0
# Afghanistan                                           0
# Afghanistan                                         390
# Afghanistan                                         390
# Afghanistan                                        1043
# ...                                                 ...
# Zimbabwe                                        2176472
# Zimbabwe                                        2178815
# Zimbabwe                                        2179147
# Zimbabwe                                        2179147
# Zimbabwe                                        2179365
#
#              Cumulative area burnt by wildfires in 2015  \
# Country
# Afghanistan                                         368
# Afghanistan                                         425
# Afghanistan                                         425
# Afghanistan                                         425
# Afghanistan                                         425
# ...                                                 ...
# Zimbabwe                                        3182494
# Zimbabwe                                        3192311
# Zimbabwe                                        3194733
# Zimbabwe                                        3195377
# Zimbabwe                                        3196594
#
#              Cumulative area burnt by wildfires in 2014  \
# Country
# Afghanistan                                           0
# Afghanistan                                         426
# Afghanistan                                         426
# Afghanistan                                         426
# Afghanistan                                         426
# ...                                                 ...
# Zimbabwe                                        2831917
# Zimbabwe                                        2861358
# Zimbabwe                                        2862483
# Zimbabwe                                        2862758
# Zimbabwe                                        2863008
#
#              Cumulative area burnt by wildfires in 2013  \
# Country
# Afghanistan                                           0
# Afghanistan                                           0
# Afghanistan                                          54
# Afghanistan                                         362
# Afghanistan                                         379
# ...                                                 ...
# Zimbabwe                                        2556610
# Zimbabwe                                        2562822
# Zimbabwe                                        2564134
# Zimbabwe                                        2564322
# Zimbabwe                                        2564322
#
#              Cumulative area burnt by wildfires in 2012
# Country
# Afghanistan                                           0
# Afghanistan                                           0
# Afghanistan                                           0
# Afghanistan                                         368
# Afghanistan                                         597
# ...                                                 ...
# Zimbabwe                                        3266499
# Zimbabwe                                        3269141
# Zimbabwe                                        3270515
# Zimbabwe                                        3271228
# Zimbabwe                                        3271385
#
# [13416 rows x 12 columns]

# %%
world_sector_bar = area_burnt_weekly2.loc['World']
world_sector_bar.head(10)
# Out:
#          Week  Cumulative area burnt by wildfires in 2022  \
# Country
# World       1                                     6823054
# World       2                                    13529661
# World       3                                    21414932
# World       4                                    30536682
# World       5                                    37957364
# World       6                                    44874256
# World       7                                    50662508
# World       8                                    56108440
# World       9                                    61437780
# World      10                                    66994004
#
#          Cumulative area burnt by wildfires in 2021  \
# Country
# World                                       6243280
# World                                      13612986
# World                                      22073170
# World                                      28618532
# World                                      36223096
# World                                      42458070
# World                                      47555252
# World                                      53917932
# World                                      62679790
# World                                      69132490
#
#          Cumulative area burnt by wildfires in 2020  \
# Country
# World                                       8420206
# World                                      19669008
# World                                      28404578
# World                                      37736476
# World                                      44947824
# World                                      54342136
# World                                      61771468
# World                                      68793820
# World                                      75113890
# World                                      81222720
#
#          Cumulative area burnt by wildfires in 2019  \
# Country
# World                                       9185009
# World                                      17072796
# World                                      24038128
# World                                      30544302
# World                                      35374956
# World                                      42909572
# World                                      49307644
# World                                      55899440
# World                                      62130304
# World                                      68373650
#
#          Cumulative area burnt by wildfires in 2018  \
# Country
# World                                       8567571
# World                                      17328420
# World                                      24573232
# World                                      31499508
# World                                      34297624
# World                                      34745360
# World                                      35037444
# World                                      35241732
# World                                      35577944
# World                                      40997910
#
#          Cumulative area burnt by wildfires in 2017  \
# Country
# World                                       9048469
# World                                      16264442
# World                                      22874132
# World                                      28860450
# World                                      35594292
# World                                      42455560
# World                                      48022684
# World                                      54097160
# World                                      59451504
# World                                      63866090
#
#          Cumulative area burnt by wildfires in 2016  \
# Country
# World                                       9403529
# World                                      17856200
# World                                      25445644
# World                                      36577550
# World                                      46125896
# World                                      54785850
# World                                      61176708
# World                                      66080910
# World                                      70577750
# World                                      75521130
#
#          Cumulative area burnt by wildfires in 2015  \
# Country
# World                                      11393788
# World                                      21682968
# World                                      28971462
# World                                      36367916
# World                                      44216268
# World                                      49315480
# World                                      54355060
# World                                      58971150
# World                                      65211230
# World                                      72121750
#
#          Cumulative area burnt by wildfires in 2014  \
# Country
# World                                       9838285
# World                                      18297760
# World                                      26152724
# World                                      32038790
# World                                      38664290
# World                                      45378496
# World                                      52410424
# World                                      57742480
# World                                      62588764
# World                                      68342100
#
#          Cumulative area burnt by wildfires in 2013  \
# Country
# World                                       9556322
# World                                      19060834
# World                                      26736024
# World                                      33213814
# World                                      41621344
# World                                      47975000
# World                                      52651900
# World                                      59391244
# World                                      64882296
# World                                      70190610
#
#          Cumulative area burnt by wildfires in 2012
# Country
# World                                        867121
# World                                       1616295
# World                                       5366893
# World                                      13476441
# World                                      20367056
# World                                      26860696
# World                                      31831508
# World                                      37821692
# World                                      43500268
# World                                      48787748

# %%
# Export area_burnt_weekly as a CSV file.
area_burnt_weekly.to_csv("/Users/artemzalivchiy/Desktop/Project3/area-burnt-by-wildfires-by-week.csv", index=False)

# %%
world_sector_bar.plot.bar(x='Week', y=["Cumulative area burnt by wildfires in 2022","Cumulative area burnt by wildfires in 2021","Cumulative area burnt by wildfires in 2020","Cumulative area burnt by wildfires in 2019","Cumulative area burnt by wildfires in 2018","Cumulative area burnt by wildfires in 2017","Cumulative area burnt by wildfires in 2016","Cumulative area burnt by wildfires in 2015","Cumulative area burnt by wildfires in 2014","Cumulative area burnt by wildfires in 2013", "Cumulative area burnt by wildfires in 2012"], rot=25,legend=True,figsize=(20,10), 
                          title='Cumulative Area Burnt by Wildfires')
plt.xlabel('Week', fontsize=14) 
plt.ylabel('Area burnt by Wildfires 2012-2022', fontsize=14)
plt.savefig("/Users/artemzalivchiy/Desktop/Project3/Images/FigBar.png",bbox_inches='tight')

# %%
# Create a path to CSV files, read the path and print DataFrame for the second CSV file
file_path2 = ("/Users/artemzalivchiy/Desktop/Project3/3-share-of-the-total-land-area-burnt-by-wildfires-each-year.csv")
wildfires2 = pd.read_csv(file_path2)
wildfires2
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2012
# 1     Afghanistan  AFG  2013
# 2     Afghanistan  AFG  2014
# 3     Afghanistan  AFG  2015
# 4     Afghanistan  AFG  2016
# ...           ...  ...   ...
# 2657     Zimbabwe  ZWE  2018
# 2658     Zimbabwe  ZWE  2019
# 2659     Zimbabwe  ZWE  2020
# 2660     Zimbabwe  ZWE  2021
# 2661     Zimbabwe  ZWE  2022
#
#       Annual share of the total land area burnt by wildfires
# 0                                              0.015976
# 1                                              0.009025
# 2                                              0.007864
# 3                                              0.006256
# 4                                              0.014829
# ...                                                 ...
# 2657                                           6.937745
# 2658                                           7.056078
# 2659                                           3.126520
# 2660                                           5.408635
# 2661                                           7.725561
#
# [2662 rows x 4 columns]

# %%
# Rename the columns
wildfires2_rename = wildfires2.rename(columns={"Entity":"Country"})
wildfires2_rename
# Out:
#           Country Code  Year  \
# 0     Afghanistan  AFG  2012
# 1     Afghanistan  AFG  2013
# 2     Afghanistan  AFG  2014
# 3     Afghanistan  AFG  2015
# 4     Afghanistan  AFG  2016
# ...           ...  ...   ...
# 2657     Zimbabwe  ZWE  2018
# 2658     Zimbabwe  ZWE  2019
# 2659     Zimbabwe  ZWE  2020
# 2660     Zimbabwe  ZWE  2021
# 2661     Zimbabwe  ZWE  2022
#
#       Annual share of the total land area burnt by wildfires
# 0                                              0.015976
# 1                                              0.009025
# 2                                              0.007864
# 3                                              0.006256
# 4                                              0.014829
# ...                                                 ...
# 2657                                           6.937745
# 2658                                           7.056078
# 2659                                           3.126520
# 2660                                           5.408635
# 2661                                           7.725561
#
# [2662 rows x 4 columns]

# %%
# Remove 2023 and 2024, as we are only using data from 2012-2022
area_burnt_yearly = wildfires2.drop(wildfires2[wildfires2['Year'] > 2022].index)
area_burnt_yearly
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  2012
# 1     Afghanistan  AFG  2013
# 2     Afghanistan  AFG  2014
# 3     Afghanistan  AFG  2015
# 4     Afghanistan  AFG  2016
# ...           ...  ...   ...
# 2657     Zimbabwe  ZWE  2018
# 2658     Zimbabwe  ZWE  2019
# 2659     Zimbabwe  ZWE  2020
# 2660     Zimbabwe  ZWE  2021
# 2661     Zimbabwe  ZWE  2022
#
#       Annual share of the total land area burnt by wildfires
# 0                                              0.015976
# 1                                              0.009025
# 2                                              0.007864
# 3                                              0.006256
# 4                                              0.014829
# ...                                                 ...
# 2657                                           6.937745
# 2658                                           7.056078
# 2659                                           3.126520
# 2660                                           5.408635
# 2661                                           7.725561
#
# [2662 rows x 4 columns]

# %%
area_burnt_yearly2 = area_burnt_yearly.drop('Code', axis=1)
area_burnt_yearly2.set_index("Entity",inplace=True)
area_burnt_yearly2
# Out:
#              Year  Annual share of the total land area burnt by wildfires
# Entity
# Afghanistan  2012                                           0.015976
# Afghanistan  2013                                           0.009025
# Afghanistan  2014                                           0.007864
# Afghanistan  2015                                           0.006256
# Afghanistan  2016                                           0.014829
# ...           ...                                                ...
# Zimbabwe     2018                                           6.937745
# Zimbabwe     2019                                           7.056078
# Zimbabwe     2020                                           3.126520
# Zimbabwe     2021                                           5.408635
# Zimbabwe     2022                                           7.725561
#
# [2662 rows x 2 columns]

# %%
africa_data = area_burnt_yearly2.loc['Africa']
africa_data.head(10)
# Out:
#         Year  Annual share of the total land area burnt by wildfires
# Entity
# Africa  2012                                           7.659314
# Africa  2013                                           8.456222
# Africa  2014                                           7.922038
# Africa  2015                                           8.673921
# Africa  2016                                           8.820186
# Africa  2017                                           8.127977
# Africa  2018                                           6.580430
# Africa  2019                                           7.613947
# Africa  2020                                           8.014693
# Africa  2021                                           7.765831

# %%
# Export area_burnt_yearly as a CSV file.
area_burnt_yearly.to_csv("/Users/artemzalivchiy/Desktop/Project3/total-land-area-burnt-by-wildfires-each-year.csv", index=False)

# %% [markdown]
# ## Ecosystems Burnt Yearly

# %%
# Create a path to CSV files, read the path and print DataFrame for the third CSV file
file_path3 = ("/Users/artemzalivchiy/Desktop/Project3/5-annual-burned-area-by-landcover.csv")
wildfires3 = pd.read_csv(file_path3)
wildfires3
# Out:
#            Entity Code  Year  Yearly burned area across other land categories  \
# 0     Afghanistan  AFG  2002                                          0.00000
# 1     Afghanistan  AFG  2003                                       1309.41800
# 2     Afghanistan  AFG  2004                                        407.85200
# 3     Afghanistan  AFG  2005                                         85.86400
# 4     Afghanistan  AFG  2006                                       1116.22690
# ...           ...  ...   ...                                              ...
# 4930     Zimbabwe  ZWE  2018                                        837.17000
# 4931     Zimbabwe  ZWE  2019                                        472.24902
# 4932     Zimbabwe  ZWE  2020                                       1180.62290
# 4933     Zimbabwe  ZWE  2021                                        364.92000
# 4934     Zimbabwe  ZWE  2022                                        944.49700
#
#       Yearly burned area across croplands  Yearly burned area across forests  \
# 0                               14167.473                             0.0000
# 1                               21680.530                             0.0000
# 2                                4357.571                             0.0000
# 3                                1395.281                             0.0000
# 4                                9809.900                             0.0000
# ...                                   ...                                ...
# 4930                           345579.000                         36449.0430
# 4931                           344205.200                         28012.9590
# 4932                           248317.160                          8006.7695
# 4933                           292214.840                          2897.8940
# 4934                           378936.940                         11140.7860
#
#       Yearly burned area across savannas  \
# 0                                  0.000
# 1                                  0.000
# 2                                  0.000
# 3                                 64.398
# 4                                 64.398
# ...                                  ...
# 4930                          420537.800
# 4931                          357277.900
# 4932                           96081.230
# 4933                          155262.620
# 4934                          303334.160
#
#       Yearly burned area across shrublands and grasslands
# 0                                             18052.793
# 1                                            112030.360
# 2                                             24556.953
# 3                                             10883.193
# 4                                              7169.603
# ...                                                 ...
# 4930                                        1806674.800
# 4931                                        1784092.600
# 4932                                         643503.750
# 4933                                        1353895.200
# 4934                                        2080107.000
#
# [4935 rows x 8 columns]

# %%
# Rename the columns
wildfires3_rename = wildfires3.rename(columns={"Entity":"Country","Yearly burned area across other land categories":"Other",
                                               "Yearly burned area across croplands":"Croplands","Yearly burned area across forests":"Forests",
                                               "Yearly burned area across savannas":"Savannas",
                                               "Yearly burned area across shrublands and grasslands":"Shrublands/Grasslands"})
wildfires3_rename
# Out:
#           Country Code  Year       Other   Croplands     Forests    Savannas  \
# 0     Afghanistan  AFG  2002     0.00000   14167.473      0.0000       0.000
# 1     Afghanistan  AFG  2003  1309.41800   21680.530      0.0000       0.000
# 2     Afghanistan  AFG  2004   407.85200    4357.571      0.0000       0.000
# 3     Afghanistan  AFG  2005    85.86400    1395.281      0.0000      64.398
# 4     Afghanistan  AFG  2006  1116.22690    9809.900      0.0000      64.398
# ...           ...  ...   ...         ...         ...         ...         ...
# 4930     Zimbabwe  ZWE  2018   837.17000  345579.000  36449.0430  420537.800
# 4931     Zimbabwe  ZWE  2019   472.24902  344205.200  28012.9590  357277.900
# 4932     Zimbabwe  ZWE  2020  1180.62290  248317.160   8006.7695   96081.230
# 4933     Zimbabwe  ZWE  2021   364.92000  292214.840   2897.8940  155262.620
# 4934     Zimbabwe  ZWE  2022   944.49700  378936.940  11140.7860  303334.160
#
#       Shrublands/Grasslands
# 0                 18052.793
# 1                112030.360
# 2                 24556.953
# 3                 10883.193
# 4                  7169.603
# ...                     ...
# 4930            1806674.800
# 4931            1784092.600
# 4932             643503.750
# 4933            1353895.200
# 4934            2080107.000
#
# [4935 rows x 8 columns]

# %%
# Remove 2002-2011, as we are only using data from 2012-2022
area_burnt_landcover = wildfires3_rename.drop(wildfires3_rename[wildfires3_rename['Year'] < 2012].index)
area_burnt_landcover
# Out:
#           Country Code  Year       Other     Croplands     Forests  \
# 10    Afghanistan  AFG  2012     0.00000       0.00000      0.0000
# 11    Afghanistan  AFG  2013   364.91900     837.16800      0.0000
# 12    Afghanistan  AFG  2014    64.39800     150.26100      0.0000
# 13    Afghanistan  AFG  2015   171.72700     493.71500      0.0000
# 14    Afghanistan  AFG  2016   407.85100     601.04504      0.0000
# ...           ...  ...   ...         ...           ...         ...
# 4930     Zimbabwe  ZWE  2018   837.17000  345579.00000  36449.0430
# 4931     Zimbabwe  ZWE  2019   472.24902  344205.20000  28012.9590
# 4932     Zimbabwe  ZWE  2020  1180.62290  248317.16000   8006.7695
# 4933     Zimbabwe  ZWE  2021   364.92000  292214.84000   2897.8940
# 4934     Zimbabwe  ZWE  2022   944.49700  378936.94000  11140.7860
#
#         Savannas  Shrublands/Grasslands
# 10         0.000           5.559661e+03
# 11         0.000           5.946045e+03
# 12         0.000           9.659640e+02
# 13         0.000           1.481145e+03
# 14       300.523           3.091086e+03
# ...          ...                    ...
# 4930  420537.800           1.806675e+06
# 4931  357277.900           1.784093e+06
# 4932   96081.230           6.435038e+05
# 4933  155262.620           1.353895e+06
# 4934  303334.160           2.080107e+06
#
# [2585 rows x 8 columns]

# %%
# Export area_burnt_landcover as a CSV file.
area_burnt_landcover.to_csv("/Users/artemzalivchiy/Desktop/Project3/burnt_landcover.csv", index=False)

# %%
area_burnt_landcover.astype(str)
# Out:
#           Country Code  Year      Other  Croplands    Forests   Savannas  \
# 10    Afghanistan  AFG  2012        0.0        0.0        0.0        0.0
# 11    Afghanistan  AFG  2013    364.919    837.168        0.0        0.0
# 12    Afghanistan  AFG  2014     64.398    150.261        0.0        0.0
# 13    Afghanistan  AFG  2015    171.727    493.715        0.0        0.0
# 14    Afghanistan  AFG  2016    407.851  601.04504        0.0    300.523
# ...           ...  ...   ...        ...        ...        ...        ...
# 4930     Zimbabwe  ZWE  2018     837.17   345579.0  36449.043   420537.8
# 4931     Zimbabwe  ZWE  2019  472.24902   344205.2  28012.959   357277.9
# 4932     Zimbabwe  ZWE  2020  1180.6229  248317.16  8006.7695   96081.23
# 4933     Zimbabwe  ZWE  2021     364.92  292214.84   2897.894  155262.62
# 4934     Zimbabwe  ZWE  2022    944.497  378936.94  11140.786  303334.16
#
#      Shrublands/Grasslands
# 10               5559.6606
# 11                5946.045
# 12                 965.964
# 13                1481.145
# 14                3091.086
# ...                    ...
# 4930             1806674.8
# 4931             1784092.6
# 4932             643503.75
# 4933             1353895.2
# 4934             2080107.0
#
# [2585 rows x 8 columns]

# %%
drop_columns = area_burnt_landcover[["Country", "Year", "Other", "Croplands", "Forests", "Savannas", "Shrublands/Grasslands"]].copy()
drop_columns.astype(str)
drop_columns.set_index("Country",inplace=True)
drop_columns
# Out:
#              Year       Other     Croplands     Forests    Savannas  \
# Country
# Afghanistan  2012     0.00000       0.00000      0.0000       0.000
# Afghanistan  2013   364.91900     837.16800      0.0000       0.000
# Afghanistan  2014    64.39800     150.26100      0.0000       0.000
# Afghanistan  2015   171.72700     493.71500      0.0000       0.000
# Afghanistan  2016   407.85100     601.04504      0.0000     300.523
# ...           ...         ...           ...         ...         ...
# Zimbabwe     2018   837.17000  345579.00000  36449.0430  420537.800
# Zimbabwe     2019   472.24902  344205.20000  28012.9590  357277.900
# Zimbabwe     2020  1180.62290  248317.16000   8006.7695   96081.230
# Zimbabwe     2021   364.92000  292214.84000   2897.8940  155262.620
# Zimbabwe     2022   944.49700  378936.94000  11140.7860  303334.160
#
#              Shrublands/Grasslands
# Country
# Afghanistan           5.559661e+03
# Afghanistan           5.946045e+03
# Afghanistan           9.659640e+02
# Afghanistan           1.481145e+03
# Afghanistan           3.091086e+03
# ...                            ...
# Zimbabwe              1.806675e+06
# Zimbabwe              1.784093e+06
# Zimbabwe              6.435038e+05
# Zimbabwe              1.353895e+06
# Zimbabwe              2.080107e+06
#
# [2585 rows x 6 columns]

# %%
world_sector = drop_columns.loc['World']
world_sector
# Out:
#          Year      Other   Croplands     Forests     Savannas  \
# Country
# World    2012  1309332.2  29195490.0  32420588.0  156498720.0
# World    2013  1160595.2  25744938.0  28365170.0  145895140.0
# World    2014  1200521.8  30557672.0  29494316.0  146904640.0
# World    2015  1234738.4  29904144.0  32527208.0  147074670.0
# World    2016  1084412.9  28726954.0  33213514.0  151343780.0
# World    2017  1039398.9  30282780.0  30575574.0  137236510.0
# World    2018  1187513.4  22586450.0  27801884.0  139537970.0
# World    2019  1704261.2  27439538.0  34405236.0  135178750.0
# World    2020  2831906.2  27007452.0  33229506.0  147312200.0
# World    2021  2266624.0  25509522.0  30783578.0  134379660.0
# World    2022  1929760.1  24071072.0  29307928.0  133850696.0
#
#          Shrublands/Grasslands
# Country
# World              233160080.0
# World              153898700.0
# World              172331550.0
# World              173074720.0
# World              150360720.0
# World              177478430.0
# World              161991020.0
# World              145932050.0
# World              139635540.0
# World              159391280.0
# World              141455680.0

# %%
year_sector = world_sector[["Year", "Other", "Croplands", "Forests", "Savannas", "Shrublands/Grasslands"]].copy()
year_sector.astype(str)
year_sector.set_index("Year",inplace=True)
year_sector
# Out:
#           Other   Croplands     Forests     Savannas  Shrublands/Grasslands
# Year
# 2012  1309332.2  29195490.0  32420588.0  156498720.0            233160080.0
# 2013  1160595.2  25744938.0  28365170.0  145895140.0            153898700.0
# 2014  1200521.8  30557672.0  29494316.0  146904640.0            172331550.0
# 2015  1234738.4  29904144.0  32527208.0  147074670.0            173074720.0
# 2016  1084412.9  28726954.0  33213514.0  151343780.0            150360720.0
# 2017  1039398.9  30282780.0  30575574.0  137236510.0            177478430.0
# 2018  1187513.4  22586450.0  27801884.0  139537970.0            161991020.0
# 2019  1704261.2  27439538.0  34405236.0  135178750.0            145932050.0
# 2020  2831906.2  27007452.0  33229506.0  147312200.0            139635540.0
# 2021  2266624.0  25509522.0  30783578.0  134379660.0            159391280.0
# 2022  1929760.1  24071072.0  29307928.0  133850696.0            141455680.0

# %%
#Rename rows
year_sector_rename = year_sector.rename(index={2012:"2012",2013:"2013",2014:"2014",2015:"2015",2016:"2016",2017:"2017",
                                              2018:"2018",2019:"2019",2020:"2020",2021:"2021",2022:"2022"})
year_sector_rename
# Out:
#           Other   Croplands     Forests     Savannas  Shrublands/Grasslands
# Year
# 2012  1309332.2  29195490.0  32420588.0  156498720.0            233160080.0
# 2013  1160595.2  25744938.0  28365170.0  145895140.0            153898700.0
# 2014  1200521.8  30557672.0  29494316.0  146904640.0            172331550.0
# 2015  1234738.4  29904144.0  32527208.0  147074670.0            173074720.0
# 2016  1084412.9  28726954.0  33213514.0  151343780.0            150360720.0
# 2017  1039398.9  30282780.0  30575574.0  137236510.0            177478430.0
# 2018  1187513.4  22586450.0  27801884.0  139537970.0            161991020.0
# 2019  1704261.2  27439538.0  34405236.0  135178750.0            145932050.0
# 2020  2831906.2  27007452.0  33229506.0  147312200.0            139635540.0
# 2021  2266624.0  25509522.0  30783578.0  134379660.0            159391280.0
# 2022  1929760.1  24071072.0  29307928.0  133850696.0            141455680.0

# %%
year_sector_rename[:3]
# Out:
#           Other   Croplands     Forests     Savannas  Shrublands/Grasslands
# Year
# 2012  1309332.2  29195490.0  32420588.0  156498720.0            233160080.0
# 2013  1160595.2  25744938.0  28365170.0  145895140.0            153898700.0
# 2014  1200521.8  30557672.0  29494316.0  146904640.0            172331550.0

# %%
#Pie Chart for 2012-2014 (separated to make it easier to see)
world_pie = year_sector_rename[:3]['Other':'Shrublands/Grasslands']
year_sector_rename[:3].T.plot(kind='pie', legend=False, title="Type of Ecosystems Burnt per year Globally (2012-2022)", 
                              subplots=True,figsize=(20, 5),autopct='%1.0f%%')
plt.savefig("/Users/artemzalivchiy/Desktop/Project3/Images/Fig1.png",bbox_inches='tight')

# %%
#Pie Chart for 2015-2018 (separated to make it easier to see)
world_pie2 = year_sector_rename[3:7]['Other':'Shrublands/Grasslands']
year_sector_rename[3:7].T.plot(kind='pie', legend=False, 
                              subplots=True,figsize=(20, 5),autopct='%1.0f%%')
plt.savefig("/Users/artemzalivchiy/Desktop/Project3/Images/Fig2.png",bbox_inches='tight')

# %%
#Pie Chart for 2019-2022 (separated to make it easier to see)
world_pie3 = year_sector_rename[7:11]['Other':'Shrublands/Grasslands']
year_sector_rename[7:11].T.plot(kind='pie', legend=False, 
                              subplots=True,figsize=(20, 5),autopct='%1.0f%%')
plt.savefig("/Users/artemzalivchiy/Desktop/Project3/Images/Fig3.png",bbox_inches='tight')

# %%
data = pd.read_csv('/Users/artemzalivchiy/Desktop/Project3/area-burnt-by-wildfires-by-week.csv')
geolocator = Nominatim(user_agent="wildfire_map")

# Function to update the map based on dropdown selection
def update_map(country, week, year):
    # Filter data based on selected country, week, and year
    filtered_data = data[(data['Country'] == country) & (data['Week'] == week)]

    # Geocode the selected country to get its coordinates
    location = geolocator.geocode(country)
    if location:
        country_center = [location.latitude, location.longitude]
    else:
        country_center = [0, 0]  # Default to center of the map

    # Initialize a Folium map centered on the selected country
    my_map = folium.Map(location=country_center, zoom_start=4)

    # Add Markers for the selected country, week, and year
    for index, row in filtered_data.iterrows():
        popup_text = f"<b>{country}</b><br>"
        popup_text += f"Week: {week}<br>"
        popup_text += f"Wildfire area {year} Hectares: {row[f'Cumulative area burnt by wildfires in {year}']}<br>"
        folium.Marker(location=country_center, popup=popup_text).add_to(my_map)

    # Display the map
    display(my_map)

# Get unique country names and weeks
country_names = data['Country'].unique().tolist()
weeks = data['Week'].unique().tolist()
years = [int(col.split()[-1]) for col in data.columns if col.startswith('Cumulative area burnt by wildfires')]

# Create dropdown widgets
country_dropdown = Dropdown(options=country_names, description='Country:')
week_dropdown = Dropdown(options=weeks, description='Week:')
year_dropdown = Dropdown(options=years, description='Year:')

# Display interactive dropdowns
interact(update_map, country=country_dropdown, week=week_dropdown, year=year_dropdown);
# Out:
# interactive(children=(Dropdown(description='Country:', options=('Afghanistan', 'Africa', 'Akrotiri and Dhekeli…

# %%
# Load the CSV file
df = pd.read_csv("/Users/artemzalivchiy/Desktop/Project3/total-land-area-burnt-by-wildfires-each-year.csv")

# Initialize the Dash app
app = dash.Dash(__name__)

# Define the layout of the app
app.layout = html.Div([
    html.H1("Wildfires Data Visualization"),
    dcc.Dropdown(
        id='country-dropdown',
        options=[{'label': country, 'value': country} for country in df['Entity'].unique()],
        value=df['Entity'].unique()[0]
    ),
    dcc.Graph(id='bubble-chart')
])

# Define callback to update the bubble chart based on dropdown selection
@app.callback(
    Output('bubble-chart', 'figure'),
    [Input('country-dropdown', 'value')]
)
def update_bubble_chart(selected_country):
    filtered_df = df[df['Entity'] == selected_country]
    fig = px.scatter(filtered_df, x='Year', y='Annual share of the total land area burnt by wildfires',
                     size='Annual share of the total land area burnt by wildfires', hover_name='Year')
    fig.update_layout(title=f"Wildfires Data for {selected_country}",
                      xaxis_title="Year",
                      yaxis_title="Annual share of the total land area burnt by wildfires",
                      hovermode='closest')
    return fig

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
